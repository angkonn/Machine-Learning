# %%
from IPython.display import Image, display
display(Image('/content/Screenshot_20241207_100623.png'))
display(Image('/content/ss2.png'))

# %% [markdown]
# # **Types of Gradient Descents**
#
# 1. Batch Gradient Descent (BGD)
# 2. Stochastic Gradient Descent (SGD)
# 3. Mini-Batch Gradient Descent

# %%
from IPython.display import Image,display
# display(Image(''))
display(Image('/content/ss4.png'))
display(Image('/content/ss5.png'))
display(Image('/content/ss6.png'))
display(Image('/content/ss8.png'))
display(Image('/content/ss7.png'))
display(Image('/content/ss9.png'))
