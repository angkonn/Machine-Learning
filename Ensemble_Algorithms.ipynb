# %%
from IPython.display import Image, display


image_files = [
    '/content/Screenshot_20250308_055038.png',
    '/content/Screenshot_20250308_055552.png',
    '/content/Screenshot_20250308_055930.png',
    '/content/Screenshot_20250308_060222.png'

]


for image_file in image_files:
    display(Image(filename=image_file))

# %%
from IPython.display import Image, display


image_files = [
    '/content/Screenshot_20250308_105829.png'

]


for image_file in image_files:
    display(Image(filename=image_file))
