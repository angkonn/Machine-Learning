# %%
from IPython.display import Image, display


image_files = [
               '/content/Screenshot_20250309_105912.png',
               '/content/Screenshot_20250309_105920.png',
               '/content/Screenshot_20250309_110331.png',
               '/content/Screenshot_20250309_110406.png',
               '/content/Screenshot_20250309_110417.png',
               '/content/Screenshot_20250309_110427.png',
               '/content/Screenshot_20250309_110443.png'
                ]


for image_file in image_files:
    display(Image(filename=image_file))
