# %%
from IPython.display import Image
display(Image('/content/ss (7).png'))
display(Image('/content/ss (6).png'))
display(Image('/content/ss (5).png'))
display(Image('/content/ss (4).png'))
display(Image('/content/ss (3).png'))
display(Image('/content/ss (2).png'))
display(Image('/content/ss (1).png'))

# %%
df= pd.read_csv("home data.csv")
df.head()
# Out:
#            x          y
# 0  48.955889  60.723602
# 1  44.687196  82.892504
# 2  60.297327  97.379897
# 3  45.618644  48.847153
# 4  38.816818  56.877213

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df.shape
# Out:
# (99, 2)

# %% [markdown]
# rows, n = 99
# columns: 2

# %%
x = df['x']
y = df['y']

# %% [markdown]
# ### Gradient Descent In ML

# %%
# First step:

# m-> Gradient
m = 0
# c-> intercept
c = 0
# Learning rate
Learning_rate = 0.0001
n = int(len(x))
iterations = 1000


# Second Step:
for i in range(iterations):
  y_prediction = m*x + c
  derivatives_m = (-2/n) * sum(x*(y-y_prediction))
  derivatives_c = (-2/n) * sum(y-y_prediction)
  m = m - Learning_rate * derivatives_m
  c = c - Learning_rate * derivatives_c


print("m = ",m)
print("c = ",c)
# Out:
# m =  1.4796491688881985
# c =  0.10148121497503648

# %% [markdown]
# ### Making predictions

# %%
x1 = float(input("Enter any value of x: "))
# y = mx+c
y = m*x1 + c
print("y = ",y)
# Out:
# Enter any value of x: 38.816818
# y =  57.5367537075595
