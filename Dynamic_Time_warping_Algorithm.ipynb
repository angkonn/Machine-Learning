# %% [markdown]
# Distance Based Algorithm but not typical

# %%
from IPython.display import Image, display


image_files = [
    '/content/Screenshot_20250315_123852.png',
    '/content/Screenshot_20250315_124017.png',
    '/content/Screenshot_20250315_124757.png',
    '/content/Screenshot_20250315_124942.png',
    '/content/Screenshot_20250315_125127.png',
    '/content/Screenshot_20250315_125249.png',
    '/content/Screenshot_20250315_125254.png'



]


for image_file in image_files:
    display(Image(filename=image_file))
