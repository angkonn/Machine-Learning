# %% [markdown]
# A function
# **𝑓 is convex if, for any two points**
# 𝑥 and
# 𝑦 in its domain, and any
# 𝜆 such that **0 ≤ 𝜆 ≤ 1**, the following inequality holds:
#
# **𝑓
# (
# 𝜆
# 𝑥
# +
# (
# 1
# −
# 𝜆
# )
# 𝑦
# )
# ≤
# 𝜆
# 𝑓
# (
# 𝑥
# )
# (
# 1
# −
# 𝜆
# )
# 𝑓
# (
# 𝑦
# )
# .
# f ( λ x + ( 1 − λ ) y) ≤ λ f (x) + (1 − λ) f(y)**
#
# This means the value of the function at any point on the straight line (convex combination of
# 𝑥
# x and
# 𝑦
# y) is less than or equal to the weighted average of the function's values at
# 𝑥
# x and
# 𝑦
# y.

# %% [markdown]
# When
# **𝜆
# =
# 0**, the point is at
# 𝑦, because the expression becomes:
# 0
# ⋅
# 𝑥
# +
# 1
# ⋅
# 𝑦
# =
# 𝑦
# 0⋅x+1⋅y=y
#
# When
# 𝜆
# =
# 1, the point is at
# 𝑥, because the expression becomes:
# 1
# ⋅
# 𝑥
# +
# 0
# ⋅
# 𝑦
# =
# 𝑥
# 1⋅x+0⋅y=x
#
# When
# 𝜆 is between 0 and 1, the point is somewhere between
# 𝑥
# x and
# 𝑦, with the exact location depending on the value of
# 𝜆.

# %%
from IPython.display import Image, display
display(Image('/Screenshot_20241207_094009.png'))
display(Image('/Screenshot_20241207_094603.png'))
display(Image('//ss3.png'))
display(Image('/Screenshot_20241207_095347.png'))
